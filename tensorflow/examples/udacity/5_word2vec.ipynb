# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
from itertools import compress

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'originated', 'term', 'a', 'of', 'term', 'as', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 6.950130
# Nearest to use: straining, determinism, lecoq, withdrawal, equites, dream, horseback, colleagues,
# Nearest to first: inhibitory, stellated, marinetti, phage, disabling, mcmahon, matsui, indefinite,
# Nearest to a: aramaic, steam, charted, withdrawing, analysts, monocotyledons, cup, encamped,
# Nearest to if: nanyang, subunit, remission, reprisals, wy, seamlessly, minstrel, stamps,
# Nearest to american: seoul, care, sportsman, aykroyd, intermediate, cooperation, integrate, edited,
# Nearest to will: polymorphism, custer, cpan, amitabh, composing, docs, amphetamines, dido,
# Nearest to had: ddo, struck, cobol, cesium, calvino, souls, solvent, assessment,
# Nearest to from: smear, jill, jewellery, sturgeon, hlich, industries, spectroscopy, parchment,
# Nearest to however: reacted, condon, traders, provers, pretentious, manifests, own, upscale,
# Nearest to during: weekdays, tripolitania, gavrilo, perceived, moyen, mrnas, originated, rebelled,
# Nearest to world: pegasus, bingham, wo, criswell, restless, redeemer, prerogative, magnetometer,
# Nearest to their: crannog, situation, forever, mainstays, masts, rouge, oxides, boasts,
# Nearest to an: uncovering, languedoc, nanda, siena, fanfiction, rumford, holocene, fusing,
# Nearest to also: excitement, baker, harpists, absent, cj, scam, legnica, toot,
# Nearest to this: en, specify, amoeboid, hsuan, bia, theses, ins, amman,
# Nearest to which: groening, luddite, pimp, improperly, tyranny, counteract, stowe, loops,
# Average loss at step 2000: 4.410229
# Average loss at step 4000: 3.932297
# Average loss at step 6000: 3.785121
# Average loss at step 8000: 3.720637
# Average loss at step 10000: 3.707911
# Nearest to use: esv, simulating, moh, rcaf, boyz, cladogram, salam, horseback,
# Nearest to first: pardon, marinetti, over, largest, marcos, greta, alphorn, poetically,
# Nearest to a: yeltsin, the, shy, stillborn, any, vesalius, ghosts, cato,
# Nearest to if: alain, lansbury, nanyang, grbac, is, scheme, where, revealed,
# Nearest to american: care, seoul, inhabits, cooperation, kami, citadel, electors, rwanda,
# Nearest to will: can, may, would, incursion, could, custer, might, yet,
# Nearest to had: have, has, was, were, calvino, are, deduces, pradesh,
# Nearest to from: in, on, with, for, by, relocate, schottenheimer, infielders,
# Nearest to however: traders, carlisle, thus, inevitability, lichens, gh, pretentious, flagship,
# Nearest to during: in, gavrilo, puddle, moyen, tripolitania, prohibiting, rebelled, eiga,
# Nearest to world: freire, lothal, redeemer, defensively, palliative, conjuring, researcher, warranty,
# Nearest to their: his, its, the, pruitt, some, frey, distinguishable, siege,
# Nearest to an: the, roommates, languedoc, cnt, rpc, mineralogical, fbi, stimulus,
# Nearest to also: not, still, which, often, it, that, he, foley,
# Nearest to this: it, which, that, theologian, nobody, poul, the, villein,
# Nearest to which: that, this, also, it, policymakers, catalogue, linear, pimp,
# Average loss at step 12000: 3.595981
# Average loss at step 14000: 3.635242
# Average loss at step 16000: 3.483352
# Average loss at step 18000: 3.599596
# Average loss at step 20000: 3.549928
# Nearest to use: simulating, crates, moh, esv, boyz, compel, mahatma, impedes,
# Nearest to first: second, third, largest, poetically, next, store, superintendence, pardon,
# Nearest to a: the, any, vesalius, yeltsin, possessions, rnsson, semicolon, beget,
# Nearest to if: when, alain, lansbury, grbac, nanyang, revealed, outdated, kamchatka,
# Nearest to american: sos, care, british, b, mclean, vx, english, contaminated,
# Nearest to will: can, would, may, could, might, should, cannot, yet,
# Nearest to had: has, have, was, were, deduces, is, accounted, would,
# Nearest to from: into, at, relocate, after, infielders, altered, in, on,
# Nearest to however: that, lichens, thus, carlisle, traders, oise, although, which,
# Nearest to during: in, gavrilo, through, plunkett, puddle, tripolitania, into, raccoons,
# Nearest to world: baen, teal, aguilera, mellor, aphelion, defensively, yerba, lothal,
# Nearest to their: his, its, the, some, frey, your, spontaneously, siege,
# Nearest to an: roommates, mineralogical, cnt, draining, unscrupulous, infection, loran, fusing,
# Nearest to also: which, still, often, not, who, there, appropriations, bullough,
# Nearest to this: which, it, what, dependable, queries, that, theologian, iuds,
# Nearest to which: that, this, also, it, what, who, but, usually,
# Average loss at step 22000: 3.479711
# Average loss at step 24000: 3.571437
# Average loss at step 26000: 3.516475
# Average loss at step 28000: 3.424053
# Average loss at step 30000: 3.458063
# Nearest to use: crates, rcaf, gradually, compel, simulating, murad, duns, jef,
# Nearest to first: second, largest, third, last, poetically, same, next, destry,
# Nearest to a: the, any, beget, yeltsin, frey, polyphony, godzilla, another,
# Nearest to if: when, where, lansbury, alain, although, though, is, should,
# Nearest to american: british, contaminated, care, orthography, english, clarendon, conjugations, circe,
# Nearest to will: would, can, may, could, should, might, cannot, must,
# Nearest to had: has, have, was, were, been, never, would, downed,
# Nearest to from: into, including, infielders, relocate, altered, on, after, by,
# Nearest to however: but, that, although, which, where, when, lichens, there,
# Nearest to during: after, in, through, gavrilo, when, puddle, tripolitania, within,
# Nearest to world: baen, mellor, teal, slugger, council, reputation, earth, post,
# Nearest to their: its, his, the, some, her, your, cnidarians, spontaneously,
# Nearest to an: mineralogical, roommates, stimulus, cnt, anatta, rpc, daniel, loran,
# Nearest to also: still, often, which, who, bronchitis, usually, gardening, now,
# Nearest to this: it, which, that, the, some, what, always, bombers,
# Nearest to which: that, this, what, who, also, it, still, usually,
# Average loss at step 32000: 3.467407
# Average loss at step 34000: 3.468699
# Average loss at step 36000: 3.470441
# Average loss at step 38000: 3.455027
# Average loss at step 40000: 3.456217
# Nearest to use: decins, moh, gradually, crates, compel, expert, boyz, munro,
# Nearest to first: second, last, third, largest, next, same, poetically, following,
# Nearest to a: any, the, rajendra, vesalius, another, unpopularity, progenitors, petn,
# Nearest to if: when, where, although, then, while, though, for, dilapidated,
# Nearest to american: british, english, contaminated, clarendon, care, orthography, jaws, independent,
# Nearest to will: would, can, may, could, might, should, cannot, must,
# Nearest to had: has, have, was, were, having, deduces, downed, been,
# Nearest to from: into, through, after, coyote, by, tagus, including, during,
# Nearest to however: but, although, that, which, lichens, though, where, they,
# Nearest to during: after, through, until, while, in, when, before, at,
# Nearest to world: earth, baen, mellor, slugger, kazakhstan, post, replacement, reputation,
# Nearest to their: its, his, her, your, some, the, our, these,
# Nearest to an: oxides, cnt, mineralogical, roommates, conformations, anatta, stimulus, loran,
# Nearest to also: still, often, which, who, uncontroversial, bronchitis, it, generally,
# Nearest to this: it, which, what, queries, the, desperation, hittites, sainte,
# Nearest to which: that, what, this, also, however, still, virus, but,
# Average loss at step 42000: 3.364376
# Average loss at step 44000: 3.327185
# Average loss at step 46000: 3.431765
# Average loss at step 48000: 3.327022
# Average loss at step 50000: 3.348832
# Nearest to use: compel, voice, moh, crates, fall, most, munro, boyz,
# Nearest to first: second, next, same, last, third, reviewing, largest, poetically,
# Nearest to a: any, the, another, every, yeltsin, llewellyn, godzilla, no,
# Nearest to if: when, where, though, although, because, so, ve, dilapidated,
# Nearest to american: british, english, french, care, contaminated, livius, kirov, protectionist,
# Nearest to will: would, can, could, may, should, might, must, cannot,
# Nearest to had: has, have, was, were, having, since, been, never,
# Nearest to from: through, into, in, under, between, relocate, including, while,
# Nearest to however: but, although, though, while, that, where, they, lossless,
# Nearest to during: after, through, at, within, in, before, until, afghani,
# Nearest to world: baen, earth, mellor, hyperlinks, aguilera, slugger, reputation, teal,
# Nearest to their: its, his, her, the, your, our, spontaneously, whose,
# Nearest to an: roommates, mineralogical, draining, cnt, sore, anatta, loran, daniel,
# Nearest to also: often, still, which, usually, now, who, typically, bronchitis,
# Nearest to this: it, which, what, the, that, hittites, some, wingers,
# Nearest to which: that, this, what, also, usually, who, virus, flatus,
# Average loss at step 52000: 3.414877
# Average loss at step 54000: 3.296074
# Average loss at step 56000: 3.449748
# Average loss at step 58000: 3.391381
# Average loss at step 60000: 3.379290
# Nearest to use: compel, moh, voice, fall, difficult, teenaged, munro, need,
# Nearest to first: second, last, next, third, following, bcl, same, mycenaean,
# Nearest to a: another, any, enhanced, the, yeltsin, ustawa, no, vesalius,
# Nearest to if: when, where, though, although, since, so, before, after,
# Nearest to american: british, english, care, contaminated, orthography, clarendon, asian, french,
# Nearest to will: would, can, could, may, should, must, might, cannot,
# Nearest to had: has, have, were, was, having, since, relocate, been,
# Nearest to from: through, into, tagus, between, relocate, in, near, under,
# Nearest to however: but, although, that, where, though, which, thus, he,
# Nearest to during: after, in, while, since, within, through, throughout, before,
# Nearest to world: upholds, slugger, wells, earth, largest, lothal, baen, mellor,
# Nearest to their: its, his, her, your, our, the, both, werewolves,
# Nearest to an: mineralogical, draining, roommates, sore, another, cnt, consultation, integration,
# Nearest to also: often, still, now, which, usually, never, gardening, bronchitis,
# Nearest to this: it, which, what, hittites, dependable, some, he, the,
# Nearest to which: that, this, what, also, however, it, usually, where,
# Average loss at step 62000: 3.194219
# Average loss at step 64000: 3.414008
# Average loss at step 66000: 3.382863
# Average loss at step 68000: 3.397334
# Average loss at step 70000: 3.419075
# Nearest to use: compel, voice, moh, most, candidates, teenaged, tate, infrequently,
# Nearest to first: last, second, third, next, same, following, original, final,
# Nearest to a: isotopic, abducted, clippers, no, another, any, filmmaking, lullaby,
# Nearest to if: when, where, though, then, feel, ve, although, because,
# Nearest to american: british, english, australian, contaminated, french, italian, orthography, african,
# Nearest to will: would, can, could, may, must, might, should, cannot,
# Nearest to had: has, have, was, were, having, never, been, previously,
# Nearest to from: into, through, after, before, during, between, simplest, liturgical,
# Nearest to however: but, although, that, though, where, when, there, while,
# Nearest to during: after, before, through, until, in, when, since, within,
# Nearest to world: upholds, kazakhstan, wells, goldfish, earth, lothal, warranty, slugger,
# Nearest to their: its, his, your, her, our, whose, spontaneously, the,
# Nearest to an: draining, mineralogical, sore, rpc, consultation, roommates, cnt, decameron,
# Nearest to also: often, now, still, usually, generally, which, never, sometimes,
# Nearest to this: it, which, what, the, hittites, some, that, there,
# Nearest to which: that, what, this, who, also, there, however, always,
# Average loss at step 72000: 3.404341
# Average loss at step 74000: 3.363459
# Average loss at step 76000: 3.249354
# Average loss at step 78000: 3.352333
# Average loss at step 80000: 3.404053
# Nearest to use: compel, voice, stag, moh, wolff, achieve, deuterocanonical, teenaged,
# Nearest to first: second, last, next, third, same, best, original, current,
# Nearest to a: the, any, or, every, yeltsin, filmmaking, another, clippers,
# Nearest to if: when, though, where, then, before, ve, for, while,
# Nearest to american: british, australian, english, italian, french, contaminated, african, asian,
# Nearest to will: would, can, could, must, may, should, might, cannot,
# Nearest to had: has, have, having, were, was, never, been, attended,
# Nearest to from: through, into, by, metaxas, for, in, bpm, using,
# Nearest to however: but, although, though, when, that, while, where, thus,
# Nearest to during: after, before, throughout, within, until, under, through, since,
# Nearest to world: upholds, earth, baen, mission, post, mon, year, lothal,
# Nearest to their: its, his, her, your, our, whose, the, some,
# Nearest to an: mineralogical, draining, consultation, sore, malignant, equinoctial, roommates, anatta,
# Nearest to also: often, which, still, now, usually, generally, sometimes, who,
# Nearest to this: which, it, that, what, there, itself, wingers, another,
# Nearest to which: that, this, also, who, what, usually, there, these,
# Average loss at step 82000: 3.334062
# Average loss at step 84000: 3.304985
# Average loss at step 86000: 3.370195
# Average loss at step 88000: 3.352015
# Average loss at step 90000: 3.356845
# Nearest to use: compel, stag, lose, semiconductors, because, cartan, teenaged, diluted,
# Nearest to first: last, second, next, third, original, best, same, marketable,
# Nearest to a: another, the, filmmaking, any, progenitors, yeltsin, every, enhanced,
# Nearest to if: when, though, where, before, although, after, however, windy,
# Nearest to american: british, italian, australian, english, contaminated, french, african, including,
# Nearest to will: would, could, can, must, might, may, should, cannot,
# Nearest to had: has, have, was, were, began, having, ventricle, never,
# Nearest to from: through, in, into, bettors, kickboxing, on, fangio, rhombicuboctahedron,
# Nearest to however: but, although, though, that, when, while, where, haider,
# Nearest to during: after, in, before, throughout, within, through, under, until,
# Nearest to world: sweet, earth, baen, kazakhstan, lothal, year, civil, cylinders,
# Nearest to their: its, his, her, your, our, whose, my, the,
# Nearest to an: mineralogical, draining, equinoctial, sore, another, consultation, roommates, unscrupulous,
# Nearest to also: often, still, now, usually, never, which, typically, generally,
# Nearest to this: which, it, what, there, another, wingers, that, snafu,
# Nearest to which: this, that, what, also, who, usually, agade, these,
# Average loss at step 92000: 3.368657
# Average loss at step 94000: 3.305214
# Average loss at step 96000: 3.210754
# Average loss at step 98000: 3.362663
# Average loss at step 100000: 3.274583
# Nearest to use: because, compel, fruits, issue, lose, khaldun, shrinking, acknowledge,
# Nearest to first: last, second, next, third, original, best, same, following,
# Nearest to a: another, the, yeltsin, any, filmmaking, every, conductive, vesalius,
# Nearest to if: when, though, then, where, before, after, swnt, so,
# Nearest to american: british, english, italian, australian, contaminated, french, african, asian,
# Nearest to will: would, could, can, must, may, might, should, cannot,
# Nearest to had: has, have, was, having, since, been, were, began,
# Nearest to from: through, into, without, using, in, burglar, between, altercation,
# Nearest to however: although, but, though, while, when, that, where, cases,
# Nearest to during: after, before, in, throughout, within, until, following, since,
# Nearest to world: earth, slugger, kazakhstan, civil, country, upholds, mission, winter,
# Nearest to their: its, his, your, her, our, the, whose, spontaneously,
# Nearest to an: draining, cnt, rpc, malignant, mineralogical, equinoctial, orientations, horne,
# Nearest to also: still, often, now, which, never, sometimes, commonly, typically,
# Nearest to this: which, it, the, what, some, another, that, any,
# Nearest to which: that, this, also, what, usually, who, but, often,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
	'''
	Batch generator for CBOW (Continuous Bag of Words).
	batch should be a shape of (batch_size, num_skips)
	Parameters
	----------
	data: list of index of words
	batch_size: number of words in each mini-batch
	num_skips: number of surrounding words on both direction (2: one word ahead and one word following)
	skip_window: number of words at both ends of a sentence to skip (1: skip the first and last word of a sentence)
	'''
	global data_index
	assert batch_size % num_skips == 0
	assert num_skips <= 2 * skip_window
	batch = np.ndarray(shape=(batch_size, num_skips), dtype=np.int32)
	labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
	span = 2 * skip_window + 1 # [ skip_window target skip_window ]
	buffer = collections.deque(maxlen=span) # used for collecting data[data_index] in the sliding window
	# collect the first window of words
	for _ in range(span):
		buffer.append(data[data_index])
		data_index = (data_index + 1) % len(data)
	# move the sliding window  
	for i in range(batch_size):
		mask = [1] * span
		mask[skip_window] = 0 
		batch[i, :] = list(compress(buffer, mask)) # all surrounding words
		labels[i, 0] = buffer[skip_window] # the word at the center 
		buffer.append(data[data_index])
		data_index = (data_index + 1) % len(data)
	return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    #print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    #print('    batch:', [reverse_dictionary[bi] for bi in batch])
    #print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  #train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, num_skips])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  #embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  embed = tf.zeros([batch_size, embedding_size])
  for j in range(num_skips):
    embed += tf.nn.embedding_lookup(embeddings, train_dataset[:, j])
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.326736
# Nearest to all: bofors, coup, pickles, ebola, stabbing, theron, slay, bacon,
# Nearest to eight: woolwich, buckley, cays, titicaca, abruzzo, genera, mccarthy, cassel,
# Nearest to in: phys, upsurge, abruptly, drc, embedded, spectacles, arose, fidonet,
# Nearest to after: enact, arrian, mannheim, uzziah, constructed, legged, carneiro, undoing,
# Nearest to or: locke, bacchus, glance, enforcement, mandatory, danelaw, rpr, fluoxetine,
# Nearest to than: gantry, foraminifera, oratio, geospatial, incidents, apollo, mutagenic, benchers,
# Nearest to are: exciting, superset, moo, drinkers, handing, dominos, hector, certified,
# Nearest to many: deutscher, clocked, stipulation, equilibria, nz, ideologies, vocation, duel,
# Nearest to which: room, heraclea, jacks, phenomenology, minted, laxness, bio, beginning,
# Nearest to who: politician, radiation, uris, menachem, acp, jonas, avoid, polarised,
# Nearest to zero: analogies, eleazar, taiwan, lm, molotov, diver, statement, settling,
# Nearest to is: sqrat, mourning, usps, lulach, scum, entrances, seater, buchner,
# Nearest to on: athanasius, lustre, bookseller, snows, mccoy, storey, session, danes,
# Nearest to some: eon, specimen, seizing, superorder, knesset, gathers, backplane, miracles,
# Nearest to during: geoffroy, cameroons, flavouring, models, jacoby, integrals, loxodonta, apart,
# Nearest to and: lune, multiplied, leverage, colin, film, steadily, vaccinations, blurring,
# Average loss at step 2000: 4.090961
# Average loss at step 4000: 3.562093
# Average loss at step 6000: 3.391991
# Average loss at step 8000: 3.244654
# Average loss at step 10000: 3.177884
# Nearest to all: some, many, passau, these, coup, traditions, mime, mayfield,
# Nearest to eight: nine, six, four, seven, five, three, zero, two,
# Nearest to in: at, on, from, sncf, during, within, with, mellow,
# Nearest to after: when, remington, ihra, before, hilberg, in, crops, pt,
# Nearest to or: and, than, et, craig, lodge, sniper, borel, eurythmics,
# Nearest to than: or, gantry, foraminifera, sauropods, karaca, recessions, metro, possibly,
# Nearest to are: were, is, have, was, be, tremor, longue, abnormal,
# Nearest to many: some, several, other, preston, all, kelp, bocks, these,
# Nearest to which: that, also, who, this, it, what, but, phenomenology,
# Nearest to who: he, which, often, magyars, modernists, they, realised, gunfire,
# Nearest to zero: four, eight, five, nine, seven, six, three, two,
# Nearest to is: was, has, are, became, intrigue, cliques, does, exists,
# Nearest to on: in, upon, agar, at, gallery, racecourse, nominal, through,
# Nearest to some: many, all, several, these, nottingham, various, most, any,
# Nearest to during: in, at, despite, loxodonta, flavouring, cameroons, vinyl, integrals,
# Nearest to and: or, boardgamegeek, boosted, lodge, relinquish, blues, persecuting, bradford,
# Average loss at step 12000: 3.206382
# Average loss at step 14000: 3.153961
# Average loss at step 16000: 3.182931
# Average loss at step 18000: 3.123553
# Average loss at step 20000: 2.988474
# Nearest to all: some, many, both, any, families, romanization, mime, these,
# Nearest to eight: six, seven, nine, four, five, three, zero, two,
# Nearest to in: during, at, under, of, leslie, computable, featuring, with,
# Nearest to after: before, when, ihra, without, during, hilberg, padres, remington,
# Nearest to or: and, than, aka, manifest, normandie, lodge, lorica, abercorn,
# Nearest to than: or, holmes, metro, much, sauropods, zilog, halfwidth, graceland,
# Nearest to are: were, have, is, include, cameroun, be, timetable, grundlagen,
# Nearest to many: some, several, these, various, doonesbury, preston, bocks, all,
# Nearest to which: that, this, also, who, philippine, it, but, impassioned,
# Nearest to who: he, which, actually, often, also, always, she, they,
# Nearest to zero: six, seven, five, four, eight, nine, three, x,
# Nearest to is: was, has, are, be, does, became, cumin, being,
# Nearest to on: upon, at, oilseed, transonic, vah, in, through, nominal,
# Nearest to some: many, these, several, various, any, all, both, bocks,
# Nearest to during: at, in, through, vinyl, despite, by, impulse, after,
# Nearest to and: or, but, like, volunteered, discernible, sussex, restoring, bayonne,
# Average loss at step 22000: 3.075075
# Average loss at step 24000: 3.039582
# Average loss at step 26000: 3.001887
# Average loss at step 28000: 3.028691
# Average loss at step 30000: 3.008579
# Nearest to all: both, some, any, many, those, these, every, clary,
# Nearest to eight: nine, seven, six, four, five, three, zero, two,
# Nearest to in: during, within, since, of, from, throughout, on, under,
# Nearest to after: before, when, during, if, ihra, following, while, without,
# Nearest to or: and, multiplayer, than, including, wield, gunfight, kama, interpretive,
# Nearest to than: much, holmes, sauropods, or, and, metro, expensive, oracles,
# Nearest to are: were, is, have, include, grundlagen, cameroun, was, abnormal,
# Nearest to many: some, several, various, these, bocks, most, preston, doonesbury,
# Nearest to which: that, this, who, what, impassioned, pew, however, usually,
# Nearest to who: which, he, actually, modernists, they, also, still, always,
# Nearest to zero: five, seven, four, nine, eight, six, three, bc,
# Nearest to is: was, are, has, became, seems, showed, becomes, remains,
# Nearest to on: upon, in, mitigate, through, nominal, townspeople, brotherhood, agar,
# Nearest to some: many, several, these, any, various, most, all, doonesbury,
# Nearest to during: after, in, despite, before, at, under, within, battista,
# Nearest to and: or, but, including, however, although, like, upside, than,
# Average loss at step 32000: 2.830467
# Average loss at step 34000: 2.958005
# Average loss at step 36000: 2.946796
# Average loss at step 38000: 2.940622
# Average loss at step 40000: 2.937697
# Nearest to all: both, various, some, every, many, any, clary, shaman,
# Nearest to eight: nine, seven, six, five, four, three, zero, two,
# Nearest to in: during, within, throughout, since, from, sncf, among, solent,
# Nearest to after: before, when, during, if, without, while, following, hilberg,
# Nearest to or: and, than, normandie, while, initio, aruban, remy, botany,
# Nearest to than: but, much, or, while, zilog, holmes, hogan, halfwidth,
# Nearest to are: were, have, include, is, although, braudel, been, including,
# Nearest to many: some, several, various, most, bocks, both, these, those,
# Nearest to which: this, that, what, who, also, impassioned, usually, these,
# Nearest to who: he, which, actually, they, usually, often, modernists, commendation,
# Nearest to zero: five, seven, eight, six, four, nine, three, cet,
# Nearest to is: was, has, becomes, became, are, seems, does, remains,
# Nearest to on: upon, through, bernoulli, at, within, agar, inside, piloting,
# Nearest to some: many, several, various, most, both, any, these, all,
# Nearest to during: in, after, within, despite, when, before, throughout, battista,
# Nearest to and: or, but, while, pinstripes, although, including, suffix, unneeded,
# Average loss at step 42000: 2.948671
# Average loss at step 44000: 2.959828
# Average loss at step 46000: 2.907665
# Average loss at step 48000: 2.867822
# Average loss at step 50000: 2.847419
# Nearest to all: both, several, various, many, some, every, those, these,
# Nearest to eight: nine, seven, four, six, five, three, zero, two,
# Nearest to in: during, within, at, from, throughout, near, mellow, sncf,
# Nearest to after: before, during, when, without, while, until, following, transsexual,
# Nearest to or: and, than, inadvertent, but, while, comcast, sized, visibly,
# Nearest to than: or, much, even, antiaircraft, but, holmes, likely, tco,
# Nearest to are: were, is, have, while, be, include, communicates, although,
# Nearest to many: some, several, various, these, certain, all, most, few,
# Nearest to which: that, what, this, impassioned, usually, also, typically, these,
# Nearest to who: actually, he, commendation, remorse, magyars, subunit, often, modernists,
# Nearest to zero: five, seven, eight, nine, four, six, three, two,
# Nearest to is: was, has, are, contains, becomes, became, seems, be,
# Nearest to on: upon, through, agar, at, litters, in, vah, under,
# Nearest to some: many, several, any, these, various, most, certain, all,
# Nearest to during: after, in, within, before, until, when, following, throughout,
# Nearest to and: or, but, giambattista, demobilization, while, including, boardgamegeek, beaverbrook,
# Average loss at step 52000: 2.890917
# Average loss at step 54000: 2.866568
# Average loss at step 56000: 2.854986
# Average loss at step 58000: 2.752047
# Average loss at step 60000: 2.832112
# Nearest to all: various, many, both, several, certain, some, any, tsarevich,
# Nearest to eight: nine, seven, six, four, five, three, zero, two,
# Nearest to in: during, within, at, near, under, on, among, from,
# Nearest to after: before, during, when, if, without, while, despite, following,
# Nearest to or: and, than, initio, corridors, slings, tesla, though, botany,
# Nearest to than: or, sauropods, antiaircraft, even, much, tco, olden, carpathian,
# Nearest to are: were, include, is, have, vols, workloads, be, cameroun,
# Nearest to many: some, several, various, few, certain, all, numerous, these,
# Nearest to which: that, this, also, what, impassioned, actually, pew, who,
# Nearest to who: actually, he, often, still, which, commendation, they, remorse,
# Nearest to zero: five, seven, four, nine, eight, six, three, x,
# Nearest to is: was, contains, are, has, seems, becomes, does, remains,
# Nearest to on: upon, through, within, around, at, in, under, litters,
# Nearest to some: many, several, any, certain, most, various, this, all,
# Nearest to during: after, in, within, when, at, before, despite, until,
# Nearest to and: but, or, although, vs, including, suffix, giambattista, who,
# Average loss at step 62000: 2.835917
# Average loss at step 64000: 2.774207
# Average loss at step 66000: 2.762105
# Average loss at step 68000: 2.714894
# Average loss at step 70000: 2.788874
# Nearest to all: both, various, many, several, calabria, opportunities, every, certain,
# Nearest to eight: nine, six, seven, five, four, zero, three, two,
# Nearest to in: during, within, under, near, throughout, on, until, at,
# Nearest to after: before, during, when, despite, following, without, if, from,
# Nearest to or: and, than, normandie, initio, tesla, dairy, quartering, overheard,
# Nearest to than: or, much, afewerki, holmes, berengar, antiaircraft, carpathian, sauropods,
# Nearest to are: were, include, have, is, including, those, tend, be,
# Nearest to many: some, several, numerous, various, those, these, few, both,
# Nearest to which: that, this, impassioned, what, also, usually, typically, agricola,
# Nearest to who: he, actually, she, which, now, they, still, remorse,
# Nearest to zero: eight, five, seven, six, four, nine, three, two,
# Nearest to is: was, seems, has, contains, became, are, becomes, be,
# Nearest to on: upon, within, in, at, through, under, during, around,
# Nearest to some: many, several, certain, various, any, numerous, these, most,
# Nearest to during: after, in, throughout, before, although, within, despite, under,
# Nearest to and: or, but, persecuting, giambattista, including, although, haircut, cdots,
# Average loss at step 72000: 2.798642
# Average loss at step 74000: 2.647879
# Average loss at step 76000: 2.802276
# Average loss at step 78000: 2.826458
# Average loss at step 80000: 2.783936
# Nearest to all: both, various, many, any, every, some, several, certain,
# Nearest to eight: nine, six, seven, five, four, zero, three, two,
# Nearest to in: within, during, throughout, at, near, on, under, through,
# Nearest to after: before, during, when, while, despite, although, for, without,
# Nearest to or: and, though, than, hilberg, initio, carbonate, but, unclaimed,
# Nearest to than: or, much, antiaircraft, sitcoms, magnification, carpathian, even, ammi,
# Nearest to are: were, include, have, is, contain, tend, exist, gavrilo,
# Nearest to many: some, several, numerous, various, few, both, those, most,
# Nearest to which: that, this, impassioned, typically, but, usually, what, agricola,
# Nearest to who: he, which, she, actually, still, remorse, often, also,
# Nearest to zero: five, eight, six, seven, nine, four, three, u,
# Nearest to is: was, has, becomes, contains, remains, are, seems, became,
# Nearest to on: upon, around, in, through, within, during, under, regarding,
# Nearest to some: many, several, certain, any, these, numerous, various, both,
# Nearest to during: after, throughout, in, before, although, until, when, despite,
# Nearest to and: or, including, but, persecuting, giambattista, of, indifferent, although,
# Average loss at step 82000: 2.666948
# Average loss at step 84000: 2.770240
# Average loss at step 86000: 2.736928
# Average loss at step 88000: 2.750873
# Average loss at step 90000: 2.741316
# Nearest to all: both, various, many, none, some, every, most, any,
# Nearest to eight: seven, six, nine, four, five, three, zero, two,
# Nearest to in: during, within, on, throughout, from, near, at, through,
# Nearest to after: before, when, during, while, without, despite, if, though,
# Nearest to or: and, than, wield, although, initio, while, though, without,
# Nearest to than: or, even, antiaircraft, compulsion, limbs, carpathian, grammatically, haired,
# Nearest to are: were, include, is, have, exist, including, transhuman, remain,
# Nearest to many: some, several, numerous, various, both, few, those, all,
# Nearest to which: this, that, also, typically, what, impassioned, who, pew,
# Nearest to who: he, still, actually, which, they, she, also, koto,
# Nearest to zero: five, six, seven, eight, four, nine, three, million,
# Nearest to is: was, has, are, contains, exists, became, becomes, provides,
# Nearest to on: upon, in, through, concerning, around, within, at, regarding,
# Nearest to some: many, several, certain, any, most, all, these, various,
# Nearest to during: throughout, in, after, before, despite, when, around, within,
# Nearest to and: or, including, giambattista, vs, but, although, borel, goodall,
# Average loss at step 92000: 2.684383
# Average loss at step 94000: 2.724070
# Average loss at step 96000: 2.705645
# Average loss at step 98000: 2.369134
# Average loss at step 100000: 2.403878
# Nearest to all: both, many, various, some, several, patty, every, elevators,
# Nearest to eight: nine, seven, six, five, four, zero, three, two,
# Nearest to in: during, at, near, within, throughout, outside, since, mellow,
# Nearest to after: before, when, during, following, without, despite, for, within,
# Nearest to or: and, initio, than, visibly, pauly, though, but, quisling,
# Nearest to than: or, sitcoms, carpathian, ammi, magnification, much, even, compulsion,
# Nearest to are: were, include, have, exist, contain, is, tend, remain,
# Nearest to many: some, several, numerous, various, those, all, both, few,
# Nearest to which: what, that, this, also, typically, instead, impassioned, actually,
# Nearest to who: often, he, actually, still, also, typically, they, usually,
# Nearest to zero: six, eight, five, seven, four, nine, three, two,
# Nearest to is: was, became, has, seems, does, remains, becomes, are,
# Nearest to on: upon, at, news, agar, through, concerning, around, rubenstein,
# Nearest to some: many, several, certain, any, all, various, numerous, these,
# Nearest to during: at, after, in, throughout, before, despite, until, under,
# Nearest to and: or, but, including, giambattista, lipsius, demarcated, beaverbrook, nor,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
